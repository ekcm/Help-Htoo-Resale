# %%
# import relevant library
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
# read csv file
url = "transformed_df_features2.csv"
HDB_resale_df = pd.read_csv(url)

# %%
HDB_resale_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142422 entries, 0 to 142421
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   month                     142422 non-null  object
#  1   town                      142422 non-null  object
#  2   flat_type                 142422 non-null  object
#  3   block                     142422 non-null  object
#  4   street_name               142422 non-null  object
#  5   storey_range              142422 non-null  object
#  6   floor_area_sqm            142422 non-null  float64
#  7   flat_model                142422 non-null  object
#  8   lease_commence_date       142422 non-null  int64
#  9   remaining_lease           142422 non-null  object
#  10  resale_price              142422 non-null  float64
#  11  adjusted_resale_price     142422 non-null  float64
#  12  transaction_year          142422 non-null  int64
# ...

# %%
one_hot_encoded_data = pd.get_dummies(HDB_resale_df, columns = ['flat_type', 'flat_model', 'storey_range'])
one_hot_encoded_data
# Out:
#           month        town block        street_name  floor_area_sqm  \
# 0       2017-01  ANG MO KIO   406  ANG MO KIO AVE 10            44.0
# 1       2017-01  ANG MO KIO   108   ANG MO KIO AVE 4            67.0
# 2       2017-01  ANG MO KIO   602   ANG MO KIO AVE 5            67.0
# 3       2017-01  ANG MO KIO   465  ANG MO KIO AVE 10            68.0
# 4       2017-01  ANG MO KIO   601   ANG MO KIO AVE 5            67.0
# ...         ...         ...   ...                ...             ...
# 142417  2022-02      YISHUN   633       YISHUN ST 61           171.0
# 142418  2022-02      YISHUN   632       YISHUN ST 61           164.0
# 142419  2022-05      YISHUN   605       YISHUN ST 61           163.0
# 142420  2022-09      YISHUN   633       YISHUN ST 61           164.0
# 142421  2022-10      YISHUN   633       YISHUN ST 61           171.0
#
#         lease_commence_date     remaining_lease  resale_price  \
# 0                      1979  61 years 04 months      232000.0
# ...

# %%
one_hot_encoded_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142422 entries, 0 to 142421
# Data columns (total 73 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   month                              142422 non-null  object
#  1   town                               142422 non-null  object
#  2   block                              142422 non-null  object
#  3   street_name                        142422 non-null  object
#  4   floor_area_sqm                     142422 non-null  float64
#  5   lease_commence_date                142422 non-null  int64
#  6   remaining_lease                    142422 non-null  object
#  7   resale_price                       142422 non-null  float64
#  8   adjusted_resale_price              142422 non-null  float64
#  9   transaction_year                   142422 non-null  int64
#  10  transaction_month                  142422 non-null  int64
# ...

# %%
one_hot_encoded_data.to_csv('transformed_df_encoding.csv', index = False)

# %%
HDB_resale_df
# Out:
#           month        town         flat_type block        street_name  \
# 0       2017-01  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1       2017-01  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2       2017-01  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3       2017-01  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4       2017-01  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# ...         ...         ...               ...   ...                ...
# 142417  2022-02      YISHUN  MULTI-GENERATION   633       YISHUN ST 61
# 142418  2022-02      YISHUN  MULTI-GENERATION   632       YISHUN ST 61
# 142419  2022-05      YISHUN  MULTI-GENERATION   605       YISHUN ST 61
# 142420  2022-09      YISHUN  MULTI-GENERATION   633       YISHUN ST 61
# 142421  2022-10      YISHUN  MULTI-GENERATION   633       YISHUN ST 61
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...
